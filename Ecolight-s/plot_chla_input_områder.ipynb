# %% [markdown]
# ## Plotting the input chla in the model to see seasonal changes here, so it can be compared to the seasonal changes in RRS

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
data_2023 = pd.read_csv("data/inputs_2023.csv")
data_2025 = pd.read_csv("data/inputs_2025.csv")
data_new_2025 = pd.read_csv("data/inputs_new_2025.csv")


# Extract the 'chla_mg_m3' column
chla_values_2023 = data_2023['chla_mg_m3'].values
chla_values_2025 = data_2025['chla_mg_m3'].values
chla_values_new_2025 = data_new_2025['chla_mg_m3'].values

# Optional: print or inspect the values
print(chla_values_2023)

plt.figure(figsize=(10, 5))
#plt.plot(chla_values_2023, marker='o', linestyle='-', color='green')
#plt.plot(chla_values_2025, marker='o', linestyle='-', color='red')
plt.plot(chla_values_new_2025, marker='o', linestyle='-', color='blue')
plt.grid(True, alpha=0.3)
plt.title("Chlorophyll-a Concentration Over Samples")
plt.xlabel("Sample Index")
plt.ylabel("Chlorophyll-a (mg/m³)")
plt.grid(True)
plt.tight_layout()
plt.show()
# Out:
# [2.25109901 2.11812894 1.60743403 1.66960372 1.09443826 6.26686384
#  7.21592404 4.09854766 1.97728067 2.24198636 6.59262207 7.67487676
#  5.26836632 2.7419322  3.20130606 7.56047368 8.13539401 6.33688898
#  3.59293265 2.94252993 6.49668992 8.41106721 4.73862401 4.91741302
#  3.83985471 6.49757182 6.9618041  4.78451915 4.95884951 3.88508189
#  1.53270821 1.58577489 1.86627569 1.70729996 1.5997493  0.36369339
#  0.37655315 1.14246986 1.07987784 1.16816663]

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the CSV file
data_2023 = pd.read_csv("data/inputs_2023.csv")
data_2025 = pd.read_csv("data/inputs_2025.csv")
data_new_2025 = pd.read_csv("data/inputs_new_2025.csv")

# Extract the 'chla_mg_m3' column
chla_values_2023 = data_2023['chla_mg_m3'].values
chla_values_2025 = data_2025['chla_mg_m3'].values
chla_values_new_2025 = data_new_2025['chla_mg_m3'].values

A1_23 = []
A2_23 = []
A3_23 = []
A4_23 = []
A5_23 = []

A1_25 = []
A2_25 = []
A3_25 = []
A4_25 = []
A5_25 = []

A1_new_25 = []
A2_new_25 = []
A3_new_25 = []
A4_new_25 = []
A5_new_25 = []

# %%
for i in range(0,len(chla_values_2023),5):
    A1_23.append(chla_values_2023[i])
    A2_23.append(chla_values_2023[i+1])
    A3_23.append(chla_values_2023[i+2])
    A4_23.append(chla_values_2023[i+3])
    A5_23.append(chla_values_2023[i+4])

for i in range(0,len(chla_values_2025),5):
    A1_25.append(chla_values_2025[i])
    A2_25.append(chla_values_2025[i+1])
    A3_25.append(chla_values_2025[i+2])
    A4_25.append(chla_values_2025[i+3])
    A5_25.append(chla_values_2025[i+4])

for i in range(0,len(chla_values_new_2025),5):
    A1_new_25.append(chla_values_new_2025[i])
    A2_new_25.append(chla_values_new_2025[i+1])
    A3_new_25.append(chla_values_new_2025[i+2])
    A4_new_25.append(chla_values_new_2025[i+3])
    A5_new_25.append(chla_values_new_2025[i+4])

print(A1_23)
# Out:
# [np.float64(2.251099015), np.float64(6.266863843), np.float64(6.59262207), np.float64(7.560473681), np.float64(6.496689918), np.float64(6.497571825), np.float64(1.532708215), np.float64(0.363693388)]

# %%
date_strings_2025_new = [
    "15-Mar-2025 12:00:00", "22-Mar-2025 12:00:00", "29-Mar-2025 12:00:00",
    "05-Apr-2025 12:00:00", "12-Apr-2025 12:00:00", "19-Apr-2025 12:00:00",
    "26-Apr-2025 12:00:00", "03-May-2025 12:00:00", "10-May-2025 12:00:00",
    "17-May-2025 12:00:00"
]

date_string_2025 = ["02-04-2025 11:46:00",
"23-04-2025 10:28:00",
"04-05-2025 11:25:00",
"11-05-2025 10:25:00"]

date_string_2023 = ["16-03-2023 10:44:00",
"28-03-2023 10:59:00",
"29-03-2023 10:44:00",
"30-03-2023 10:30:00",
"07-04-2023 10:07:00",
"12-04-2023 10:27:00",
"14-06-2023 10:03:00",
"30-07-2023 10:17:00"]

dates_new_2025 = pd.to_datetime(date_strings_2025_new, format="%d-%b-%Y %H:%M:%S")
dates_2025 = pd.to_datetime(date_string_2025, format="%d-%m-%Y %H:%M:%S")
dates_2023 = pd.to_datetime(date_string_2023, format="%d-%m-%Y %H:%M:%S")

# %%
plt.figure(figsize=(10, 5))
#plt.plot(chla_values_2023, marker='o', linestyle='-', color='green')
#plt.plot(chla_values_2025, marker='o', linestyle='-', color='red')

### 2023
#plt.plot(A1_23, marker='o', linestyle='-', color='#808000')
#plt.plot(A2_23, marker='o', linestyle='-', color='#3cb44b')
#plt.plot(A3_23, marker='o', linestyle='-', color='#911eb4')
#plt.plot(A4_23, marker='o', linestyle='-', color='#0082c8')
#plt.plot(A5_23, marker='o', linestyle='-', color='#f58231')
#
### 2025
#plt.plot(A1_25, marker='o', linestyle='-', color='#808000')
#plt.plot(A2_25, marker='o', linestyle='-', color='#3cb44b')
#plt.plot(A3_25, marker='o', linestyle='-', color='#911eb4')
#plt.plot(A4_25, marker='o', linestyle='-', color='#0082c8')
#plt.plot(A5_25, marker='o', linestyle='-', color='#f58231')

## new 2025
#plt.plot(dates_new_2025, A1_new_25, marker='o', linestyle='-', color='#808000', label = "A1 new 2025")
#plt.plot(dates_new_2025, A2_new_25, marker='o', linestyle='-', color='#3cb44b', label = "A2 new 2025")
#plt.plot(dates_new_2025, A3_new_25, marker='o', linestyle='-', color='#911eb4', label = "A3 new 2025")
#plt.plot(dates_new_2025, A4_new_25, marker='o', linestyle='-', color='#0082c8', label = "A4 new 2025")
plt.plot(dates_new_2025, A5_new_25, marker='o', linestyle='-', color='#f58231', label = "A5 new 2025")

plt.grid(True, alpha=0.3)
plt.title("Chlorophyll-a Concentration Over Samples 2025, one sample every week")
plt.xlabel("Sample Index")
plt.ylabel("Chlorophyll-a (mg/m³)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig('plots/2025_new_cla_input.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10, 5))

### 2025
plt.plot(dates_2025, A1_25, marker='o', linestyle='-', color='#808000', label = "A1 2025")
plt.plot(dates_2025, A2_25, marker='o', linestyle='-', color='#3cb44b', label = "A2 2025")
plt.plot(dates_2025, A3_25, marker='o', linestyle='-', color='#911eb4', label = "A3 2025")
plt.plot(dates_2025, A4_25, marker='o', linestyle='-', color='#0082c8', label = "A4 2025")
plt.plot(dates_2025, A5_25, marker='o', linestyle='-', color='#f58231', label = "A5 2025")

plt.grid(True, alpha=0.3)
plt.title("Chl-a Concentration over Samples 2025")
plt.xlabel("Sample Index")
plt.ylabel("Chlorophyll-a [mg/m³]")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig('plots/2025_old_cla_input.pdf', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(10, 5))#plt.plot(chla_values_2023, marker='o', linestyle='-', color='green')#plt.plot(chla_values_2025, marker='o', linestyle='-', color='red')

## 2023
print(A1_23)
#plt.plot(A1_23, marker='o', linestyle='-', color='#808000', label = "A1 2023")
plt.plot(dates_2023, A1_23, marker='o', linestyle='-', color='#808000', label = "A1 2023") ## hvis du vil ha bare nummer på x aksen så bare fjerer du hele alle dates, og lar det A1_23 være første verdi i plot greia :))
plt.plot(dates_2023, A2_23, marker='o', linestyle='-', color='#3cb44b', label = "A2 2023")
plt.plot(dates_2023, A3_23, marker='o', linestyle='-', color='#911eb4', label = "A3 2023")
plt.plot(dates_2023, A4_23, marker='o', linestyle='-', color='#0082c8', label = "A4 2023")
plt.plot(dates_2023, A5_23, marker='o', linestyle='-', color='#f58231', label = "A5 2023")

plt.grid(True, alpha=0.3)
plt.title("Chlorophyll-a Concentration Over Samples 2023")
plt.xlabel("Sample Index")
plt.ylabel("Chlorophyll-a (mg/m³)")
plt.grid(True)
plt.legend()
plt.tight_layout()
plt.savefig('plots/2023_cla_input.pdf', dpi=300, bbox_inches='tight')
plt.show()
# Out:
# [np.float64(2.251099015), np.float64(6.266863843), np.float64(6.59262207), np.float64(7.560473681), np.float64(6.496689918), np.float64(6.497571825), np.float64(1.532708215), np.float64(0.363693388)]
